# %%
# libraries for linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
df = pd.read_csv("salary_data.csv")
df.head()

#deleting the column 
df=df.drop(columns=["salary_greater_then_average"])
df.head()

#x bhanya hamiley predict kelley garni ho bhanney
X = df[['years_experience']]
y= df.salary #or df["salary"]

# %%
#Train Test Split 
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size= 0.80, random_state= 123)
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 298 75 298 75

# %%
#Modeling
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_,model.intercept_)
# Out:
# [6768.18626592] 33142.84001530059

# %%
print(model.score(X_test, y_test))
# Out:
# 0.8804380397629219

# %%
#predicting
y_pred= model.predict(X_test)
print(y_pred[0:5], y_test[0:5])
# Out:
# [ 53447.39881305 141433.82026998  53447.39881305 161738.37906774
#  114361.07520631] 150     45000.0
# 354    160000.0
# 54      50000.0
# 102    150000.0
# 320    130000.0
# Name: salary, dtype: float64

# %%
# plot line with scatter plot
sns.scatterplot(x=df['years_experience'], y=df['salary'])
sns.lineplot(x=df['years_experience'], y=model.predict(df[['years_experience']]), color="pink")
plt.show()

# %%
#Model Evaluating
mae =mean_absolute_error(y_test, y_pred)
mse =mean_squared_error(y_test, y_pred)
r2=r2_score(y_test, y_pred)
print((mae, mse, r2))
# Out:
# (12164.468916492611, 295994923.2780767, 0.8804380397629219)

# %% [markdown]
# ## Multi linear Regression

# %%
df
# Out:
#       age  years_experience    salary
# 0    32.0               5.0   90000.0
# 1    28.0               3.0   65000.0
# 2    45.0              15.0  150000.0
# 3    36.0               7.0   60000.0
# 4    52.0              20.0  200000.0
# ..    ...               ...       ...
# 368  35.0               8.0   85000.0
# 369  43.0              19.0  170000.0
# 370  29.0               2.0   40000.0
# 371  34.0               7.0   90000.0
# 372  44.0              15.0  150000.0
#
# [373 rows x 3 columns]

# %%
#Multi linear Regression
X = df[['years_experience', "age"]]
y= df.salary #or df["salary"]

# %%
#Train Test Split 
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size= 0.80, random_state= 123)
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 298 75 298 75

# %%
#Modeling
model=LinearRegression()
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
print(model.coef_,model.intercept_)
# Out:
# 0.88404111946549
# [4860.89312695 1799.3515368 ] -14999.97085637528

# %%
#predicting
y_pred= model.predict(X_test)
print(y_pred[0:5], y_test[0:5])
# Out:
# [ 51763.9030916  143745.13833075  51763.9030916  165525.2238588
#  113505.45660215] 150     45000.0
# 354    160000.0
# 54      50000.0
# 102    150000.0
# 320    130000.0
# Name: salary, dtype: float64

# %%
#Model Evaluating
mae =mean_absolute_error(y_test, y_pred)
mse =mean_squared_error(y_test, y_pred)
r2=r2_score(y_test, y_pred)
print((mae, mse, r2))
# Out:
# (12128.391418211522, 287074918.13587505, 0.88404111946549)
